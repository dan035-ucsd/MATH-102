# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = np.linspace(-5, 5, 100)
y1 = -1/2 * x
y2 = -1/2 * x + 1
y3 = -1/2 * x - 1
y4 = -1/2 * x + 2
y5 = -1/2 * x - 2
ax.plot(x, y1)
ax.plot(x, y2)
ax.plot(x, y3)
ax.plot(x, y4)
ax.plot(x, y5)
ax.legend()
ax.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('y = -1/2 * x + c')
# Out:
# C:\Users\Dani\AppData\Local\Temp\ipykernel_68872\2625671930.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# Text(0.5, 1.0, 'y = -1/2 * x + c')

# %%
fig, ax = plt.subplots()
x = np.linspace(-5, 5, 100)
y1 = np.arctan(x)
y2 = np.arctan(x) + 1
y3 = np.arctan(x) - 1
y4 = np.arctan(x) + 2
y5 = np.arctan(x) - 2
ax.plot(x, y1)
ax.plot(x, y2)
ax.plot(x, y3)
ax.plot(x, y4)
ax.plot(x, y5)
ax.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('y = arctan(x) + c')
# Out:
# Text(0.5, 1.0, 'y = arctan(x) + c')

# %%
plt.rcParams['text.usetex'] = True
fig, ax = plt.subplots()
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
z = Y ** 2 - X ** 2

ax.contour(X, Y, z, levels=25, cmap='viridis')
ax.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title(r'$\xi = y^2 - x^2$')
# Out:
# Text(0.5, 1.0, '$\\xi = y^2 - x^2$')
