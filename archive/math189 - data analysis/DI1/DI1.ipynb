# %%
import numpy as np
import pandas as pd

Auto = pd.read_csv('Auto.csv')
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
# 9b
quantitative_vars = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']
ranges = {}
for var in quantitative_vars:
    ranges[var] = np.max(var) - np.min(var)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 ranges = {}
#       4 for var in quantitative_vars:
# ----> 5     ranges[var] = np.max(var) - np.min(var)
#
# File ~/anaconda3/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3164, in max(a, axis, out, keepdims, initial, where)
#    3052 @array_function_dispatch(_max_dispatcher)
#    3053 @set_module('numpy')
#    3054 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3055          where=np._NoValue):
#    3056     """
#    3057     Return the maximum of an array or maximum along an axis.
#    3058
#    (...)   3162     5
#    3163     """
# -> 3164     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3165                           keepdims=keepdims, initial=initial, where=where)
#
# ...
