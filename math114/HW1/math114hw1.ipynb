# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# add plot of unit circle
fig, ax = plt.subplots(figsize=(6, 6))
circle = patches.Circle((0, 0), 1, edgecolor='green', facecolor='none', linewidth=2)
ax.add_patch(circle)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)

# generate random points and plot them
rng = np.random.default_rng(1221)
N = 1000
x = rng.uniform(-1, 1, N)
y = rng.uniform(-1, 1, N)
inside_circle = x**2 + y**2 <= 1
ax.scatter(x[inside_circle], y[inside_circle], color='green', s=1)
ax.scatter(x[~inside_circle], y[~inside_circle], color='purple', s=1)

# estimate pi
tau = inside_circle.sum()
pi_est = 4 * tau / N

# error term
error = abs(np.pi - pi_est)

(pi_est, error)
# Out:
# (np.float64(3.052), np.float64(0.08959265358979307))

# %%
rng = np.random.default_rng(218)
N = 1000
u = rng.uniform(0, 1, N)
x = []
for entry in u:
    if entry < 0.5:
        x.append(np.sqrt(2*entry))
    else:
        x.append(2 - np.sqrt(2 - 2*entry))

def f(x):
    if 0 <= x <= 1:
        return x
    elif 1 < x <= 2:  
        return 2 - x

x_series = np.arange(0, 2, 0.01)
y_series = np.vectorize(f)(x_series)

plt.hist(x, bins=100, density=True, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Target PDF')
plt.plot(x_series, y_series)

plt.show()

# %%
x = rng.uniform(0, 2, N)
y = rng.uniform(0, 0.5, N)
x_accept = []
for i in x:
    for j in y:
        if j < f(i):
            x_accept.append(i)
plt.hist(x_accept, bins=100, density=True, edgecolor='black')
# Out:
# (array([0.00644223, 0.01288445, 0.16749789, 0.11596008, 0.        ,
#         0.        , 0.        , 0.41874473, 0.        , 0.77306719,
#         0.2899002 , 0.3156691 , 0.36076469, 1.12094742, 0.81816277,
#         0.        , 0.        , 0.        , 0.48316699, 1.03719848,
#         0.54758926, 0.        , 0.        , 0.62489598, 0.6313382 ,
#         1.28844531, 0.64422266, 0.64422266, 0.        , 1.28844531,
#         1.28844531, 0.64422266, 0.64422266, 0.64422266, 0.64422266,
#         1.28844531, 0.64422266, 0.        , 0.        , 1.93266797,
#         1.28844531, 0.64422266, 3.22111328, 1.28844531, 0.64422266,
#         0.64422266, 0.        , 0.64422266, 0.64422266, 0.64422266,
#         1.28844531, 0.        , 0.        , 0.        , 0.64422266,
#         0.        , 0.        , 0.        , 2.57689062, 0.64422266,
#         0.        , 0.64422266, 1.28844531, 0.64422266, 0.        ,
#         0.        , 0.64422266, 0.        , 0.64422266, 0.        ,
#         0.        , 0.64422266, 0.        , 1.28844531, 1.28844531,
#         0.6313382 , 0.62489598, 1.79093898, 0.57335816, 0.55403148,
#         0.52182035, 0.49605144, 0.        , 0.91479617, 0.        ,
#         0.39941805, 1.10162074, 0.        , 0.32855355, 0.        ,
#         0.47672477, 0.23836238, 0.20615125, 0.        , 0.        ,
#         0.        , 0.11596008, 0.        , 0.        , 0.01932668]),
#  array([0.0055382 , 0.02545171, 0.04536523, 0.06527874, 0.08519225,
#         0.10510577, 0.12501928, 0.14493279, 0.16484631, 0.18475982,
#         0.20467333, 0.22458685, 0.24450036, 0.26441387, 0.28432739,
#         0.3042409 , 0.32415441, 0.34406793, 0.36398144, 0.38389495,
#         0.40380847, 0.42372198, 0.44363549, 0.46354901, 0.48346252,
#         0.50337603, 0.52328955, 0.54320306, 0.56311657, 0.58303008,
#         0.6029436 , 0.62285711, 0.64277062, 0.66268414, 0.68259765,
#         0.70251116, 0.72242468, 0.74233819, 0.7622517 , 0.78216522,
#         0.80207873, 0.82199224, 0.84190576, 0.86181927, 0.88173278,
#         0.9016463 , 0.92155981, 0.94147332, 0.96138684, 0.98130035,
#         1.00121386, 1.02112738, 1.04104089, 1.0609544 , 1.08086792,
#         1.10078143, 1.12069494, 1.14060846, 1.16052197, 1.18043548,
#         1.20034899, 1.22026251, 1.24017602, 1.26008953, 1.28000305,
#         1.29991656, 1.31983007, 1.33974359, 1.3596571 , 1.37957061,
#         1.39948413, 1.41939764, 1.43931115, 1.45922467, 1.47913818,
#         1.49905169, 1.51896521, 1.53887872, 1.55879223, 1.57870575,
#         1.59861926, 1.61853277, 1.63844629, 1.6583598 , 1.67827331,
#         1.69818683, 1.71810034, 1.73801385, 1.75792736, 1.77784088,
#         1.79775439, 1.8176679 , 1.83758142, 1.85749493, 1.87740844,
#         1.89732196, 1.91723547, 1.93714898, 1.9570625 , 1.97697601,
#         1.99688952]),
#  <BarContainer object of 100 artists>)
