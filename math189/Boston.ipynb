# %% [markdown]
# # Boston Data
#
# A data set containing housing values in 506 suburbs of Boston.
#
# - `crim`: per capita crime rate by town.
#
# - `zn`: proportion of residential land zoned for lots over 25,000
#           sq.ft.
#
# - `indus`: proportion of non-retail business acres per town.
#
# - `chas`: Charles River dummy variable (= 1 if tract bounds river; 0
#           otherwise).
#
# - `nox`: nitrogen oxides concentration (parts per 10 million).
#
# - `rm`: average number of rooms per dwelling.
#
# - `age`: proportion of owner-occupied units built prior to 1940.
#
# - `dis`: weighted mean of distances to five Boston employment
#           centres.
#
# - `rad`: index of accessibility to radial highways.
#
# - `tax`: full-value property-tax rate per $10,000.
#
# - `ptratio`: pupil-teacher ratio by town.
#
# - `lstat`: lower status of the population (percent).
#
# - `medv`: median value of owner-occupied homes in $1000s.
#
# ## Notes
#
# This dataset was obtained from, and is slightly modified from, the
# Boston dataset that is part of the `R` library `MASS`.  References are
# available in the MASS library.

# %%
from ISLP import load_data
Boston = load_data('Boston')
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
Boston.shape
# Out:
# (506, 13)

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
import numpy as np
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize=(6, 6))
x = 'rm'
y = 'age'
z = Boston[Boston[x] >= 8]
ax.scatter(z[x], z[y])
ax.set_xlabel(x)
ax.set_ylabel(y)
ax.set_title('Scatterplot of ' + x + ' vs ' + y)
z.describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %%
Boston.iloc[Boston.idxmax()['rm']]
# Out:
# crim         3.47428
# zn           0.00000
# indus       18.10000
# chas         1.00000
# nox          0.71800
# rm           8.78000
# age         82.90000
# dis          1.90470
# rad         24.00000
# tax        666.00000
# ptratio     20.20000
# lstat        5.29000
# medv        21.90000
# Name: 364, dtype: float64

# %%
Boston.value_counts('chas')
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
Boston.median()
# Out:
# crim         0.25651
# zn           0.00000
# indus        9.69000
# chas         0.00000
# nox          0.53800
# rm           6.20850
# age         77.50000
# dis          3.20745
# rad          5.00000
# tax        330.00000
# ptratio     19.05000
# lstat       11.36000
# medv        21.20000
# dtype: float64

# %%
Boston.iloc[Boston.idxmin()['medv']]
# Out:
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64

# %%
Boston[Boston['rm'] >= 7]
# Out:
#          crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 2     0.02729   0.0   7.07     0  0.4690  7.185  61.1  4.9671    2  242
# 4     0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622    3  222
# 40    0.03359  75.0   2.95     0  0.4280  7.024  15.8  5.4011    3  252
# 55    0.01311  90.0   1.22     0  0.4030  7.249  21.9  8.6966    5  226
# 64    0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229    3  216
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 364   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016  97.5  1.2024   24  666
# 375  19.60910   0.0  18.10     0  0.6710  7.313  97.9  1.3163   24  666
# 453   8.24809   0.0  18.10     0  0.7130  7.393  99.3  2.4527   24  666
# 482   5.73116   0.0  18.10     0  0.5320  7.061  77.0  3.4106   24  666
#
#      ptratio  lstat  medv
# 2       17.8   4.03  34.7
# 4       18.7   5.33  36.2
# ...

# %%
Boston[Boston['medv'] == Boston['medv'].min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(nrows=4, ncols=3, figsize=(8, 14))

ax[0,0].set_ylabel('crim')
ax[1,0].set_ylabel('crim')
ax[2,0].set_ylabel('crim')
ax[3,0].set_ylabel('crim')

ax[0,0].plot(Boston['zn'], Boston['crim'], 'o')
ax[0,0].set_xlabel('zn')
coef_zn = np.polyfit(Boston['zn'], Boston['crim'], 1)
linreg_zn = np.poly1d(coef_zn)
ax[0,0].plot(Boston['zn'], linreg_zn(Boston['zn']), label='Model', color='red')

ax[0,1].plot(Boston['indus'], Boston['crim'], 'o')
ax[0,1].set_xlabel('indus')
coef_indus = np.polyfit(Boston['indus'], Boston['crim'], 1)
linreg_indus = np.poly1d(coef_indus)
ax[0,1].plot(Boston['indus'], linreg_indus(Boston['indus']), label='Model', color='red')

ax[0,2].plot(Boston['chas'], Boston['crim'], 'o')
ax[0,2].set_xlabel('chas')
coef_chas = np.polyfit(Boston['chas'], Boston['crim'], 1)
linreg_chas = np.poly1d(coef_chas)
ax[0,2].plot(Boston['chas'], linreg_chas(Boston['chas']), label='Model', color='red')

ax[1,0].plot(Boston['nox'], Boston['crim'], 'o')
ax[1,0].set_xlabel('nox')
coef_nox = np.polyfit(Boston['nox'], Boston['crim'], 1)
linreg_nox = np.poly1d(coef_nox)
ax[1,0].plot(Boston['nox'], linreg_nox(Boston['nox']), label='Model', color='red')

ax[1,1].plot(Boston['rm'], Boston['crim'], 'o')
ax[1,1].set_xlabel('rm')
coef_rm = np.polyfit(Boston['rm'], Boston['crim'], 1)
linreg_rm = np.poly1d(coef_rm)
ax[1,1].plot(Boston['rm'], linreg_rm(Boston['rm']), label='Model', color='red')

ax[1,2].plot(Boston['age'], Boston['crim'], 'o')
ax[1,2].set_xlabel('age')
coef_age = np.polyfit(Boston['age'], Boston['crim'], 1)
linreg_age = np.poly1d(coef_age)
ax[1,2].plot(Boston['age'], linreg_age(Boston['age']), label='Model', color='red')

ax[2,0].plot(Boston['dis'], Boston['crim'], 'o')
ax[2,0].set_xlabel('dis')
coef_dis = np.polyfit(Boston['dis'], Boston['crim'], 1)
linreg_dis = np.poly1d(coef_dis)
ax[2,0].plot(Boston['dis'], linreg_dis(Boston['dis']), label='Model', color='red')

ax[2,1].plot(Boston['rad'], Boston['crim'], 'o')
ax[2,1].set_xlabel('rad')
coef_rad = np.polyfit(Boston['rad'], Boston['crim'], 1)
linreg_rad = np.poly1d(coef_rad)
ax[2,1].plot(Boston['rad'], linreg_rad(Boston['rad']), label='Model', color='red')

ax[2,2].plot(Boston['tax'], Boston['crim'], 'o')
ax[2,2].set_xlabel('tax')
coef_tax = np.polyfit(Boston['tax'], Boston['crim'], 1)
linreg_tax = np.poly1d(coef_tax)
ax[2,2].plot(Boston['tax'], linreg_tax(Boston['tax']), label='Model', color='red')

ax[3,0].plot(Boston['ptratio'], Boston['crim'], 'o')
ax[3,0].set_xlabel('ptratio')
coef_ptratio = np.polyfit(Boston['ptratio'], Boston['crim'], 1)
linreg_ptratio = np.poly1d(coef_ptratio)
ax[3,0].plot(Boston['ptratio'], linreg_ptratio(Boston['ptratio']), label='Model', color='red')

ax[3,1].plot(Boston['lstat'], Boston['crim'], 'o')
ax[3,1].set_xlabel('lstat')
coef_lstat = np.polyfit(Boston['lstat'], Boston['crim'], 1)
linreg_lstat = np.poly1d(coef_lstat)
ax[3,1].plot(Boston['lstat'], linreg_lstat(Boston['lstat']), label='Model', color='red')

ax[3,2].plot(Boston['medv'], Boston['crim'], 'o')
ax[3,2].set_xlabel('medv')
coef_medv = np.polyfit(Boston['medv'], Boston['crim'], 1)
linreg_medv = np.poly1d(coef_medv)
ax[3,2].plot(Boston['medv'], linreg_medv(Boston['medv']), label='Model', color='red')

np.corrcoef(Boston['dis'], Boston['crim'])
# Out:
# array([[ 1.        , -0.37967009],
#        [-0.37967009,  1.        ]])

# %%
import pandas as pd 
import statsmodels.api as sm
from sklearn import linear_model    
from ISLP.models import (ModelSpec as MS, summarize, poly)

terms = Boston.columns.drop('crim')
X = MS(terms).fit_transform(Boston)
y = Boston['crim']

model1 = sm.OLS(y, X)
results1 = model1.fit()
summarize(results1)
# Out:
#               coef  std err      t  P>|t|
# intercept  13.7784    7.082  1.946  0.052
# zn          0.0457    0.019  2.433  0.015
# indus      -0.0584    0.084 -0.698  0.486
# chas       -0.8254    1.183 -0.697  0.486
# nox        -9.9576    5.290 -1.882  0.060
# rm          0.6289    0.607  1.036  0.301
# age        -0.0008    0.018 -0.047  0.962
# dis        -1.0122    0.282 -3.584  0.000
# rad         0.6125    0.088  6.997  0.000
# tax        -0.0038    0.005 -0.730  0.466
# ptratio    -0.3041    0.186 -1.632  0.103
# lstat       0.1388    0.076  1.833  0.067
# medv       -0.2201    0.060 -3.678  0.000

# %%
col = 'chas'
y = Boston['crim']
X = pd.DataFrame ({'intercept ': np.ones(Boston.shape [0]), col: Boston[col]})
model = sm.OLS(y, X)
results = model.fit()
summarize(results)
# Out:
#              coef  std err      t  P>|t|
# intercept  3.7444    0.396  9.453  0.000
# chas      -1.8928    1.506 -1.257  0.209

# %%
x = [-0.0739, 0.5098, -1.8928, 31.2485, -2.6841, 0.1078, -1.5509, 0.6179, 0.0297, 1.1520, 0.5488, -0.3632]
y = [0.0457, -0.0584, -0.8254, -9.9576, 0.6289, -.0008, -1.0122, 0.6125, -0.0038, -0.3041, 0.1388, -0.2201]

fig, ax = subplots(figsize=(6,6))
ax.scatter(x, y)
ax.set_xlabel('Univariate regression coefficient')
ax.set_ylabel('Multiple regression coefficient')
# Out:
# Text(0, 0.5, 'Multiple regression coefficient')
